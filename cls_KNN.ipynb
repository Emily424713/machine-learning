# %% [markdown]
# <a href="https://colab.research.google.com/github/Emily424713/machine-learning/blob/beining/cls_KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# KNN MODEL FOR CLASSIFICATION

# %% [markdown]
# Install packages

# %%
import pandas as pd
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data Pre-processing

# %%
# Loaded dataset and pickle
file_path = "TrainDataset2023.xls"
df = pd.read_excel(file_path)
df.head()
target_lable="pCR (outcome)"
# model_path="model/cls_ann"
# pickle.load()

# %%
df
# Out:
#             ID  pCR (outcome)  RelapseFreeSurvival (outcome)   Age  ER  PgR  \
# 0    TRG002174              1                     144.000000  41.0   0    0
# 1    TRG002178              0                     142.000000  39.0   1    1
# 2    TRG002204              1                     135.000000  31.0   0    0
# 3    TRG002206              0                      12.000000  35.0   0    0
# 4    TRG002210              0                     109.000000  61.0   1    0
# ..         ...            ...                            ...   ...  ..  ...
# 395  TRG002948              0                      54.500000  58.5   1    0
# 396  TRG002954              0                      49.250000  34.3   0    0
# 397  TRG002958              0                      48.500000  53.3   0    0
# 398  TRG002961              0                      47.500000  68.8   1    0
# 399  TRG002962              0                      46.916667  46.0   1    0
#
# ...

# %%
# X = df.drop(columns=[target_lable, 'RelapseFreeSurvival (outcome)'])
# # X = df.drop(columns=[target_lable, 'RelapseFreeSurvival (outcome)',"ID"])
# # X

# Assign features to X
X = df.drop(columns=['ID',target_lable, 'RelapseFreeSurvival (outcome)'], axis=1)
# X = df.drop(columns=[target_lable, 'RelapseFreeSurvival (outcome)'], axis=1,inplace=True)
# X=None
X
# Out:
#       Age  ER  PgR  HER2  TrippleNegative  ChemoGrade  Proliferation  \
# 0    41.0   0    0     0                1           3              3
# 1    39.0   1    1     0                0           3              3
# 2    31.0   0    0     0                1           2              1
# 3    35.0   0    0     0                1           3              3
# 4    61.0   1    0     0                0           2              1
# ..    ...  ..  ...   ...              ...         ...            ...
# 395  58.5   1    0     1                0           3              2
# 396  34.3   0    0     0                1           3              3
# 397  53.3   0    0     0                1           2              1
# 398  68.8   1    0     0                0           3              3
# 399  46.0   1    0     0                0           2              1
#
#      HistologyType  LNStatus  TumourStage  ...  \
# 0                1         1            2  ...
# ...

# %%
# # Data imputation
# # Use regression model to do data imputation
# from sklearn.experimental import enable_iterative_imputer
# from sklearn.impute import IterativeImputer
# impute_it = IterativeImputer()
# impute_it.fit_transform(X)

# %%
# # Data imputation
# # Use KNN model to do data imputation
# from sklearn.impute import KNNImputer
# impute_knn = KNNImputer(n_neighbors=2)
# impute_knn.fit_transform(X)

# %%
# X

# %%
# Identify the outcome
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df[target_lable] = le.fit_transform(df[target_lable])
df.head()

# assign numerical label to y
y = df[target_lable]
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 395    0
# 396    0
# 397    0
# 398    0
# 399    0
# Name: pCR (outcome), Length: 400, dtype: int64

# %% [markdown]
# Feature Selection

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Create and train KNN model
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = pd.Series(knn.predict(X_test).astype(int).flatten(), index=y_test.index, name='Predicted pCR (outcome)')
y_pred
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 y_pred = pd.Series(knn.predict(X_test).astype(int).flatten(), index=y_test.index, name='Predicted pCR (outcome)')
#       2 y_pred
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/neighbors/_classification.py:246, in KNeighborsClassifier.predict(self, X)
#     244 check_is_fitted(self, "_fit_method")
#     245 if self.weights == "uniform":
# --> 246     if self._fit_method == "brute" and ArgKminClassMode.is_usable_for(
#     247         X, self._fit_X, self.metric
#     248     ):
#     249         probabilities = self.predict_proba(X)
#     250         if self.outputs_2d_:
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_pairwise_distances_reduction/_dispatcher.py:471, in ArgKminClassMode.is_usable_for(cls, X, Y, metric)
#     448 @classmethod
# ...

# %%
y_test

# %%
# Calculating Mean Absolute Error
mae = mean_absolute_error(y_test, y_pred)

print("Mean Absolute Error:", mae)

# %%
from sklearn.metrics import balanced_accuracy_score

balanced_accuracy = balanced_accuracy_score(y_test, y_pred)

print("Balanced Accuracy:", balanced_accuracy)

# %%
testdf1 = pd.read_excel('TestDatasetExample.xls')
testdf2 = pd.read_excel('TestDataset2023_SendToStudent.xls')

# %%
testdf1.replace(999, 1, inplace=True)
testdf2.replace(999, 1, inplace=True)

# %%
# make sure to drop ID
testIDs = testdf1['ID']

# %%
testdf1.drop('ID',axis=1,inplace=True)

# %%
testy_pred = knn.predict(testdf1)

# %%
results = pd.DataFrame({'ID': testIDs, 'pCR (outcome)': testy_pred})

# %%
results

# %%
# results.to_excel('test.xlsx', sheet_name='sheet1', index=False)
